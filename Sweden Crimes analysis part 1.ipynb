# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Desktop\ML\datasets_851_1557_reported.csv')
df
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 0   1950          2784               2306            120       1      105
# 1   1951          3284               2754            125       1      109
# 2   1952          3160               2608            119       1      104
# 3   1953          2909               2689            119       1      105
# 4   1954          3028               2791            126       1      107
# ..   ...           ...                ...            ...     ...      ...
# 61  2011         14988              12267           1005       2      947
# 62  2012         14734              12148            974       2      914
# 63  2013         14603              12072            896       3      837
# 64  2014         14890              12305            923       3      859
# 65  2015         15342              12803            932       3      868
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# ...

# %%
df.describe()
# Out:
#               Year  crimes.total  crimes.penal.code  crimes.person     murder  \
# count    66.000000     66.000000          66.000000      66.000000  66.000000
# mean   1982.500000  10084.257576        8695.181818     451.287879   1.757576
# std      19.196354   4223.893287        3582.148938     295.041002   0.724529
# min    1950.000000   2784.000000        2306.000000     119.000000   1.000000
# 25%    1966.250000   6152.500000        5336.000000     185.250000   1.000000
# 50%    1982.500000  11654.000000        9637.000000     370.500000   2.000000
# 75%    1998.750000  13663.750000       12002.500000     690.500000   2.000000
# max    2015.000000  15342.000000       12803.000000    1005.000000   4.000000
#
#           assault  sexual.offenses       rape  stealing.general     burglary  \
# count   66.000000        66.000000  66.000000         66.000000    66.000000
# mean   423.106061        75.318182  20.045455       5580.545455  1240.681818
# ...

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column>0])
# Out:
# house.theft             15
# vehicle.theft            7
# out.of.vehicle.theft    15
# shop.theft              15
# narcotics                4
# dtype: int64

# %%
df = df.dropna(axis = 0)
df.head()
# Out:
#     Year  crimes.total  crimes.penal.code  crimes.person  murder  assault  \
# 15  1965          5801               5090            167       3      151
# 16  1966          6063               5263            184       3      166
# 17  1967          6421               5555            189       2      173
# 18  1968          7166               6242            228       1      212
# 19  1969          7671               6036            241       1      223
#
#     sexual.offenses  rape  stealing.general  burglary  ...  vehicle.theft  \
# 15               51     8              3694      1042  ...          397.0
# 16               48     8              3736      1031  ...          350.0
# 17               49     8              3939      1086  ...          384.0
# 18               47     8              4240      1232  ...          396.0
# 19               42     8              4142      1131  ...          384.0
#
#     out.of.vehicle.theft  shop.theft  robbery  fraud  criminal.damage  \
# ...

# %% [markdown]
# ### Population growth in Sweden over the years

# %%
plt.scatter(df['Year'],df['population'])
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('POpulation Growth in Sweden')
plt.grid()
plt.show()

# %% [markdown]
# ### Total crimes analysis in sweden

# %%
x = df[['Year']]
y = df[['crimes.total']]

#scatter plot of the data

plt.scatter(x=x,y=y,)
plt.xlabel('Year')
plt.ylabel('total crimes in a year')
plt.show()

# %%
#analysing the total crimes per year in sewden using linear regression
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(trianing data)')
plt.xlabel('Year')
plt.ylabel('Total crimes')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear Regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Total crimes")
plt.show()
# Out:
# Testing data: 0.85260704532551
# Training data: 0.8625459547250095

# %%
f = np.array(2011)
print(reg.predict(f.reshape(-1,1)))
# Out:
# [[15355.13913819]]

# %% [markdown]
# ### From the linear regression model we can see that the number of crimes in sweden are increasing

# %%
#sweden total crimes using polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =7)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)

lin2 = LinearRegression()
lin2.fit(X_poly,y)

plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("total crimes")
plt.show()

# %%
#accuraty of the above model
from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.964913730477932

# %%
#sweden total crimes using polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')

plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("total crimes")
plt.show()

# %%
#accuraty of the above model
from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9646258192761816

# %% [markdown]
# ###  now let's analyze the individual crimes over the years

# %% [markdown]
# # 1. Vechicle Theft

# %%
#first lets start with vehicle theft over the years
x = df[['Year']]
y = df[['vehicle.theft']]

#scatter plot of the data

plt.scatter(x=x,y=y,)
plt.xlabel('Year')
plt.ylabel('Vehicle theft')
plt.show()

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Vehicle Theft')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Vehicle theft")
plt.show()
# Out:
# Testing data: -0.35449833994160085
# Training data: 0.028999662502898982

# %% [markdown]
# ### from the above r2 score it is clear that the linear regression is not suitable for this  vechicle theft
# Now lets check it using polynomial regression

# %%
#polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =6)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Vehicle theft")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.8051080874375857

# %%
#now increasing the degree of the model
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =8)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Vehicle theft")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.8037271276138953

# %%
#decresing the degree to best fit the model
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Vehicle theft")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.8071637580755628

# %% [markdown]
# ### Conclusion
# The vehicle theft has started decreasing after the year 1990.

# %% [markdown]
# ### House Theft

# %%
x = df[['Year']]
y = df[['house.theft']]
plt.scatter(x,y)
plt.xlabel('Year',fontsize=15)
plt.ylabel('House theft cases',fontsize=15)
plt.title('House theft analysis')
plt.show()

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('House Theft')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("House theft")
plt.show()
# Out:
# Testing data: 0.08695898482616715
# Training data: 0.029819957021219427

# %% [markdown]
# ### Linear regression model is not applicable in this

# %% [markdown]
# ### Now applying the polynomial regression model

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =5)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("House  theft")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.831604220638684

# %%
#incresing the degree to get better accuracy
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =6)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("house theft")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.8320948780759887

# %%
#again incresing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =7)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("House theft")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.8325582473473748

# %% [markdown]
# ### Conclusion
# The house theft is decreasing .

# %% [markdown]
# ### 3.Stealing.general

# %%
y=df[['stealing.general']]
x = df[['Year']]
plt.scatter(x,y)
plt.ylabel('Stealing.general')
plt.xlabel('Year')
plt.title('Stealing general crime over the years')
plt.show()

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Stetaling General')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Stealing General")
plt.show()
# Out:
# Testing data: 0.20333479679565622
# Training data: 0.1387119712052305

# %% [markdown]
# ### It is cleary visible that the linear model is not applicable here

# %% [markdown]
# ### Applying polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =5)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Stealing general")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9118630126986366

# %% [markdown]
# ### This polynomial model fits well in this

# %%
#changing the degree to get better accuracy
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Stealing General")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9121408608503311

# %%
#again changing degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =2)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Stealing General")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9006031019246257

# %% [markdown]
# ### So polynomial model of degree 3 fits well

# %% [markdown]
# ### Conlusion:
# Apart from the fact that stealing general is highest reported crime,it is decreasing after year 2000

# %% [markdown]
# ### 4.Rape

# %%
x = df[['Year']]
y = df[['rape']]
plt.scatter(x,y)
plt.ylabel('Rape')
plt.xlabel('Year')
plt.title('Rape over the years')
plt.show()

# %% [markdown]
# ### Applying linear regression model

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Rape')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Rape")
plt.show()
# Out:
# Testing data: 0.6046082649241509
# Training data: 0.7762742602487187

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =5)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Rape")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9421809619090147

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Rape")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9422743533897909

# %% [markdown]
# ### The polymonial model of degree 3 is the most apt model for this rape dataset

# %% [markdown]
# ### Conclusion:
# The number of rape cases are increasing over the years and need to be taken care of

# %% [markdown]
# ### 5.Sexual offenses

# %%
x = df[['Year']]
y = df[['sexual.offenses']]
plt.scatter(x,y)
plt.ylabel('Sexual offense')
plt.xlabel('Year')
plt.title('Sexual offense over the years')
plt.show()

# %% [markdown]
# ### Linear regression analysis

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Sexual offenses')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Sexual offenses")
plt.show()
# Out:
# Testing data: 0.7267751578084158
# Training data: 0.8482884190246035

# %% [markdown]
# The accuracy is 80% aaprox which tells that this model fits well.

# %% [markdown]
# ### Polynomail regression analysis

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Sexual offense")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9801134225093252

# %%
#predicting the value to check the accuracy
b = np.array(2014)
a = lin2.predict(poly.fit_transform(b.reshape(-1,1)))
print("No of cases in 2014:",int(a)) #shows cases almost eqaul to the cases in 2014 in the csv
# Out:
# No of cases in 2014: 193

# %% [markdown]
# The r2_score is 98% which clearly shows that this model works very well for this data set

# %%
#changing the degree

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =4)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Sexual offense")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.980103092247063

# %%
#decreasing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =2)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Sexual offense")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.979320242944872

# %% [markdown]
# The polynomial regression with degree 3 is the best fit for this data set as on increasing and decreasing the value the accuracy is decreasing

# %% [markdown]
# ### Conclusion:
# The sexual offense cases need to be taken care of they are increasing at a very high rate.

# %% [markdown]
# ### 6. Burglary

# %%
x = df[['Year']]
y = df[['burglary']]
plt.scatter(x,y)
plt.ylabel('Burglary')
plt.xlabel('Year')
plt.title('Burglary over the years')
plt.show()

# %% [markdown]
# ### Linear regression analysis

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Burglary')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Burglary")
plt.show()
# Out:
# Testing data: -0.3698957813373649
# Training data: 0.26653385656840567

# %% [markdown]
#
# As clear from the graph itself and r2_score this model is not good for the above data

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =4)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Burglary")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9033285526118942

# %% [markdown]
# Accuracy is 90%(approx) the model fits well.

# %%
#changing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =2)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Burglary")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.8690034507446478

# %% [markdown]
# The r2_score decreased.

# %%
#now increrasing the accuracy
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Burglary")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9032675833134988

# %% [markdown]
# ### So plynomial regression of degree 4 is the best fit.

# %% [markdown]
# ### Conclusion
# The burglary cases are decreasing over the years

# %% [markdown]
# ### 7.Assualt

# %%
x =df[['Year']]
y = df[['assault']]
plt.scatter(x,y)
plt.title("Assault cases over the years.")
plt.ylabel('Assault')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Linear Regression analysis

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Assault')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Assault")
plt.show()
# Out:
# Testing data: 0.9595252223667128
# Training data: 0.9644130017555901

# %% [markdown]
# This clearly shows that there is a linear relationship between the assault cases and year.The accuracy of 96% shows that this model fits very well.

# %% [markdown]
# ### Lets just try polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Assault")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9817824016708193

# %% [markdown]
# Accuracy = 98% , a bad fit model.

# %%
#changing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =5)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Assault")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.9819148892658889

# %% [markdown]
# Polynomial regression  fits well

# %%
x = np.array(2020)
a=lin2.predict(poly.fit_transform(x.reshape(-1,1)))
print("Expected rise in the cases of burglary in year 2020:",int(a))
# Out:
# Expected rise in the cases of burglary in year 2020: 945

# %% [markdown]
# ### Conclusion
# The assaults cases are increasing at a very high rate and needs to be taken care.In 2020 the expected cases are expectes to be around 945.

# %% [markdown]
# ### 8.Murder

# %%
x= df[['Year']]
y = df[['murder']]
plt.scatter(x,y)
plt.title("Murder cases over the years.")
plt.ylabel('Murder')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### from the graph it is clear that there is no relation

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =2)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Murder")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.37064242088019084

# %%
#changing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =4)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Murder")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.39246594157202674

# %% [markdown]
# ### polynomial regression also does not fit well

# %% [markdown]
# ### Linear Regression

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Murder')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Murder")
plt.show()
# Out:
# Testing data: 0.37890100177082725
# Training data: 0.24112960163898

# %% [markdown]
# ### Linear regreesion is not a good model for this.

# %% [markdown]
# ### Conclusion:
# There are very few cases of murder in Sweden. It is constantly increasing

# %% [markdown]
# ### 9.Narcotics

# %%
x = df[['Year']]
y = df[['narcotics']]
plt.scatter(x,y)
plt.title("Narcotics cases over the years.")
plt.ylabel('Narcotics')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Linear regression

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Narcotics')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Narcotics")
plt.show()
# Out:
# Testing data: 0.30959737903736195
# Training data: 0.5836545637016957

# %% [markdown]
#  Not the best fit model for this data

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =4)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Narcotics")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.7535666100074878

# %% [markdown]
#  Accuracy is average.

# %%
#changing the degree to get better accuracy
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =3)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Narcotics")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.7537757177112936

# %%
#changing degree to 5
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =5)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Narcotics")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.7533456712575782

# %% [markdown]
# So polynomial regression of  degree 4 is the best fit model.

# %% [markdown]
# ### Conclusion:
# THe rate of narcotics cases is also being increased and needs to be taken care of.

# %% [markdown]
# ### 10.Drunk Drive

# %%
x = df[['Year']]
y = df[['drunk.driving']]
plt.scatter(x,y)
plt.title("Drink and Drive cases over the years.")
plt.ylabel('Drink drive')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Linear regression analysis

# %%
#using linear model to fit the data
from sklearn.model_selection import train_test_split
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 0)

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train,y_train)
a = reg.predict(x_test)
print("Testing data:",reg.score(x_test,y_test))
print("Training data:",reg.score(x_train,y_train))
plt.scatter(x,y,label='actual')
plt.plot(x_train,reg.predict(x_train),c='red',label="predicted")
plt.title('Linear regression(Trianing data)')
plt.xlabel('Year')
plt.ylabel('Drink and drive')
plt.legend()
plt.show()
#visualize the test data set
plt.scatter(x_test,y_test,c="r")#x_test = prediction,y_test = actual
plt.plot(x_train,reg.predict(x_train),c = 'b')
plt.title("Linear regression(Testing data)")
plt.xlabel("year")
plt.ylabel("Drink and drive")
plt.show()
# Out:
# Testing data: -0.059124997030065574
# Training data: 0.11553307721186545

# %% [markdown]
# From the r2_score it is clear that this linear regression model does not fit well.

# %% [markdown]
# ### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =5)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Drink Drive")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.2622372519905042

# %% [markdown]
# Bad fit for degree 5

# %%
#changing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =4)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Drink drive")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.26259010837304775

# %%
#again changing the degree
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree =6)
X_poly = poly.fit_transform(x)

poly.fit(X_poly,y)
lin2 = LinearRegression()
lin2.fit(X_poly,y)
plt.scatter(x,y,c="b")

plt.plot(x,lin2.predict(poly.fit_transform(x)),c='r')
plt.title("Polynomial Regression")
plt.xlabel("year")
plt.ylabel("Drink Drive")
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y,lin2.predict(poly.fit_transform(x)))
print(r2)
# Out:
# 0.26186549900789813

# %% [markdown]
# Polynomial regression model also is not a good model for this dataset.

# %% [markdown]
# ### Conclusion:
# Drunk driving is increasing at a very fast rate.
